# %%
from bs4 import BeautifulSoup
import requests

# %%
html_page = requests.get('https://www.premierleague.com/tables?co=1&se=42&ha=-1') # Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') # Pass the page contents to beautiful soup for parsing

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="Premier League Table, Form Guide &amp; Season Archives" name="twitter:title"/>
# <meta content="Premier League, Football, Soccer, Official" name="keywords"/>
# <meta content="website" property="og:type"/>
# <meta content="View the latest Premier League tables, form guides and season archives, on the official website of the Premier League." name="description"/>
# <meta content="View the latest Premier League tables, form guides and season archives, on the official website of the Premier League." name="twitter:description"/>
# <meta content="https://s3.amazonaws.com/premierleague-static-files/premierleague/pl_icon.png" name="twitter:image"/>
# <meta content="Premier League Table, Form Guide &amp; Season Archives" property="og:title"/>
# <meta content="https://s3.amazonaws.com/premierleague-static-files/premierleague/pl_icon.png" property="og:image"/>
# ...

# %%
league = soup.find('div', class_="team")
league # Previewing is optional but can help you verify you are selecting what you think you are

# %%
team_info = league.findAll('td')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-9afa0c7af7f6> in <module>
# ----> 1 team_info = league.findAll('td')
#
# AttributeError: 'NoneType' object has no attribute 'findAll'

# %%
team_info

# %%
import requests
import lxml.html as lh
import pandas as pd

# %%
url='https://www.premierleague.com/tables?co=1&se=42&ha=-1'

# %%
page = requests.get(url)

# %%
doc = lh.fromstring(page.content)

# %%
tr_elements = doc.xpath('//tr')

# %%
tr_elements
# Out:
# [<Element tr at 0x11e75b778>,
#  <Element tr at 0x11e75b688>,
#  <Element tr at 0x11e75b818>,
#  <Element tr at 0x11e75b868>,
#  <Element tr at 0x11e75b8b8>,
#  <Element tr at 0x11e75b908>,
#  <Element tr at 0x11e75b958>,
#  <Element tr at 0x11e75b9a8>,
#  <Element tr at 0x11e75b9f8>,
#  <Element tr at 0x11e75ba48>,
#  <Element tr at 0x11e75ba98>,
#  <Element tr at 0x11e75bae8>,
#  <Element tr at 0x11e75bb38>,
#  <Element tr at 0x11e75bb88>,
#  <Element tr at 0x11e75bbd8>,
#  <Element tr at 0x11e75bc28>,
#  <Element tr at 0x11e75bc78>,
#  <Element tr at 0x11e75bcc8>,
#  <Element tr at 0x11e75bd18>,
#  <Element tr at 0x11e75bd68>,
#  <Element tr at 0x11e75bdb8>,
#  <Element tr at 0x11e75be08>,
#  <Element tr at 0x11e75be58>,
#  <Element tr at 0x11e75bea8>,
#  <Element tr at 0x11e75bef8>,
#  <Element tr at 0x11e75bf48>,
#  <Element tr at 0x11e75bf98>,
#  <Element tr at 0x11e776048>,
#  <Element tr at 0x11e776098>,
#  <Element tr at 0x11e7760e8>,
#  <Element tr at 0x11e776138>,
# ...

# %%
[len(T) for T in tr_elements[:100]]
# Out:
# [13,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  13,
#  1,
#  12,
#  12,
#  1,
#  12,
#  1,
#  12,
#  1,
#  12,
#  1,
#  12,
#  1,
#  12,
#  1,
#  12,
#  1,
#  12,
#  1,
#  12,
#  1,
#  12,
#  1,
#  12,
#  1,
#  12,
#  1,
#  11,
#  11,
#  1,
#  11,
#  1,
#  11,
#  1,
#  11,
#  1,
#  11,
#  1,
#  11,
#  1,
#  11,
#  1,
#  11,
#  1,
#  11,
#  11,
#  1,
#  11,
#  1,
#  11,
#  1,
#  11,
#  1,
#  11,
#  1,
#  11,
#  1,
#  11,
#  1,
#  11,
#  1]

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[2]:
    i+=1
    name=t.text_content()
    print (i,name)
    col.append((name,[]))
# Out:
# 1
#
#
#                 Liverpool
#
#
#
#                         Recent Result - Saturday 7 March 2020
#
#     LIV
#
#         2 -1
#
#     BOU
#
#
#
#
#                         Next Fixture - Monday 16 March 2020
#
#     EVE
#
#     20:00
#
#     LIV
#
#
#
#
#                     Visit Liverpool Club Page
#
#
#
#
#                     Performance Chart
#                     Compare against another team
